# %% [markdown]
# #### Trabalhando com Funções

# %%
# Definindo uma função simples

def dsa_saudacao(): # def -> define uma função
    """Esta função retorna a soma de dois números."""
    print("\nOlá, Mundo! Bem-vindo ao Python")

# %%
# Chamando a função
dsa_saudacao()
# Out:
# Olá, Mundo! Bem-vindo ao Python

# %%
# Definindo uma função que retorna um valor
def dsa_soma_numeros(a, b):
    """Esta função retona a soma de dois números."""
    return a + b

# %%
# Chamando a função e armazenando o resultado em uma variável
resultado = dsa_soma_numeros(5, 3)

# Print
print(f"O resultado da soma é: {resultado}")
# Out:
# O resultado da soma é: 8
