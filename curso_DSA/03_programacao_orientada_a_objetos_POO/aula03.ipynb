# %% [markdown]
# #### Trabalhando com Instancias da Classe (Objetos)

# %% [markdown]
# Uma classe é como um "molde" para criar objetos. Ela define um conjunto de atributos e métodos (comportamentos) que os objetos desse tipo terão.
# Um Objeto é uma instancia de uma classe. É  a entidade real, criada a partir do molde (classe), com a qual você interage em seu programa.
