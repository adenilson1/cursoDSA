# %% [markdown]
# #### Projeto2: Aplicação Full-Stack de Sistemas Bancário em Python com POO

# %% [markdown]
# Simulaçao de funcionamento de um sistema bancário digital, contemplando clientes, contas e operações financeiras básicas, como depósito, saques e extratos.
