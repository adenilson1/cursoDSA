# %% [markdown]
# ### Operadores de comporação

# %%
# Definições
x = 5
y = 10

# %%
x > y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x <= y
# Out:
# True

# %%
x >= y
# Out:
# False
