# %% [markdown]
# ### Estrutura de Dados - Dicionários

# %%
# Criando um dicionário de informações de alunos
aluno = {
    "nome" : "Bob",
    "idade" : 22,
    "curso" : "Data Sciente Para Análise Multivariada",
    "aluno_ativo" : True
}

# %%
print(f"Dicionário do aluno: {aluno}")
# Out:
# Dicionário do aluno: {'nome': 'Bob', 'idade': 22, 'curso': 'Data Sciente Para Análise Multivariada', 'aluno_ativo': True}

# %%
# Acessando um valor pela sua chave
print(f"Nome do aluno: {aluno['nome']}")
print(f"Curso: {aluno.get('curso')}") # .get() é uma forma segura de acessar chaves
# Out:
# Nome do aluno: Bob
# Curso: Data Sciente Para Análise Multivariada

# %%
# Adicionando um novo par chave-valor
aluno["cidade"] = "São Paulo"
print(f"Dicionário atualizado:\n {aluno}")
# Out:
# Dicionário atualizado:
#  {'nome': 'Bob', 'idade': 22, 'curso': 'Data Sciente Para Análise Multivariada', 'aluno_ativo': True, 'cidade': 'São Paulo'}

# %%
# Modificando um valor existente
aluno["idade"] = 23
print(f"Idade atualizada: {aluno['idade']}")
# Out:
# Idade atualizada: 23

# %%
# Removendo uma par chave - valor
del aluno["aluno_ativo"]
print(f"Dicionário após remover a chave 'ativo':\n {aluno}")
# Out:
# Dicionário após remover a chave 'ativo':
#  {'nome': 'Bob', 'idade': 23, 'curso': 'Data Sciente Para Análise Multivariada', 'cidade': 'São Paulo'}
